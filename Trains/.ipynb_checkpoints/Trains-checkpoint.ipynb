# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Transit Routes

# %%
df = pd.read_csv("National_Transit_Map_Routes.csv")

# %%
df.describe()
# Out:
#            OBJECTID    route_type   SHAPE_Length
# count  52042.000000  52042.000000   52042.000000
# mean   26021.500000      2.723531   30229.475682
# std    15023.375691      0.787019   29613.601868
# min        1.000000      0.000000       0.000000
# 25%    13011.250000      3.000000   12795.931264
# 50%    26021.500000      3.000000   21377.187556
# 75%    39031.750000      3.000000   36049.365622
# max    52042.000000      6.000000  431403.684873

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52042 entries, 0 to 52041
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   OBJECTID                    52042 non-null  int64
#  1   shape_id                    52042 non-null  object
#  2   route_id                    49368 non-null  object
#  3   agency_id                   39874 non-null  object
#  4   route_short_name            44399 non-null  object
#  5   route_long_name             39624 non-null  object
#  6   route_desc                  8208 non-null   object
#  7   route_type                  52042 non-null  int64
#  8   route_type_text             49368 non-null  object
#  9   route_url                   20287 non-null  object
#  10  route_color                 40430 non-null  object
#  11  route_color_formatted       40430 non-null  object
#  12  route_text_color            30798 non-null  object
# ...

# %%
df.head()
# Out:
#    OBJECTID  shape_id route_id agency_id route_short_name route_long_name  \
# 0         1  10002005   100089         1                2             NaN
# 1         2  10002006   100089         1                2             NaN
# 2         3  10002017   100089         1                2             NaN
# 3         4  10002019   100089         1                2             NaN
# 4         5  10003010   100173         1                3             NaN
#
#                                           route_desc  route_type  \
# 0  West Queen Anne - Downtown Seattle - Madrona Park           3
# 1  West Queen Anne - Downtown Seattle - Madrona Park           3
# 2  West Queen Anne - Downtown Seattle - Madrona Park           3
# 3  West Queen Anne - Downtown Seattle - Madrona Park           3
# 4      North Queen Anne - Downtown Seattle - Madrona           3
#
#   route_type_text                                          route_url  \
# ...

# %%
import altair as alt

# %%
list('CCCDDDEEE')
data = pd.DataFrame({'a': list('CCCDDDEEE'),
                     'b': [2, 7, 4, 1, 2, 6, 8, 4, 7]})

# %% [markdown]
# ## Playing with altair

# %%
import altair as alt
from vega_datasets import data

counties = alt.topo_feature(data.us_10m.url, 'counties')
source = data.unemployment.url

alt.Chart(counties).mark_geoshape().encode(
    color='rate:Q'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(source, 'id', ['rate'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Senator Approval Ratings

# %% [markdown]
# **Are average individual senator's approval ratings different from congress ratings?**
# "Incentive problems drive even the best people into harming the organization to help themselves. And even great managers can't always tell who's performing well vs who's playing politics. My own Congressperson has an in-district approval rating higher than 75%, as do many others. Meanwhile, Congress's overall approval rating is often below 20%."
#
# *But is this just because people support their own party and see congress as gridlocked?*

# %%
approve = pd.read_excel("JARs_sen--032910.xls")

# %%
len(approve.NAME.unique())
# Out:
# 275

# %% [markdown]
# ## Basic plotting

# %%
approve.head()
# Out:
#    OFFICE  STATE  OH      NAME  PARTY  ELECYR  ELECTP  QUESTION  POS PCT  \
# 0       3      1   1      Hill      1     NaN     NaN       1.0     60.0
# 1       3      1   2  Sparkman      1     NaN     NaN       1.0     58.0
# 2       3      1   5    Heflin      1     NaN     NaN       1.0     54.0
# 3       3      1   5    Heflin      1     NaN     NaN       1.0     55.0
# 4       3      1   5    Heflin      1     NaN     NaN       1.0     47.0
#
#    NEG PCT  ...    DATEIN DAYOUT  MONTHOUT  YEAROUT              DATEOUT  \
# 0     35.0  ...  9/1/1964    1.0       9.0   1964.0  1964-09-01 00:00:00
# 1     34.0  ...  9/1/1964    1.0       9.0   1964.0  1964-09-01 00:00:00
# 2     46.0  ...    //1988    NaN       NaN   1988.0                 1988
# 3     45.0  ...    //1989    NaN       NaN   1989.0                 1989
# 4     53.0  ...    //1995    NaN       NaN   1995.0                 1995
#
#   SAMPLE  TYPE  SOURCE  SOURCED Unnamed: 24
# ...

# %%
approve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OFFICE       5906 non-null   int64
#  1   STATE        5906 non-null   int64
#  2   OH           5906 non-null   int64
#  3   NAME         5906 non-null   object
#  4   PARTY        5906 non-null   int64
#  5   ELECYR       5581 non-null   float64
#  6   ELECTP       5572 non-null   float64
#  7   QUESTION     5824 non-null   float64
#  8   POS PCT      5903 non-null   float64
#  9   NEG PCT      5840 non-null   float64
#  10  RATING SC    5884 non-null   object
#  11  POLLSTER     5831 non-null   object
#  12  DAYIN        5650 non-null   float64
#  13  MONTHIN      5815 non-null   float64
#  14  YEARIN       5890 non-null   float64
#  15  DATEIN       5906 non-null   object
#  16  DAYOUT       5651 non-null   float64
#  17  MONTHOUT     5814 non-null   float64
# ...

# %%
approve.tail()
# Out:
#       OFFICE  STATE  OH  NAME  PARTY  ELECYR  ELECTP  QUESTION  POS PCT  \
# 5901       3     50  12  Enzi      2  2002.0     2.0       1.0     60.0
# 5902       3     50  12  Enzi      2  2002.0     2.0       1.0     61.0
# 5903       3     50  12  Enzi      2  2002.0     2.0       1.0     59.0
# 5904       3     50  12  Enzi      2  2002.0     2.0       1.0     65.0
# 5905       3     50  12  Enzi      2  2002.0     2.0       1.0     72.0
#
#       NEG PCT  ...      DATEIN DAYOUT  MONTHOUT  YEAROUT     DATEOUT SAMPLE  \
# 5901     30.0  ...   8/11/2006   13.0       8.0   2006.0   8/13/2006  600.0
# 5902     28.0  ...   9/14/2006   17.0       9.0   2006.0   9/17/2006  600.0
# 5903     32.0  ...  10/12/2006   15.0      10.0   2006.0  10/15/2006  600.0
# 5904     26.0  ...   11/8/2006   11.0      11.0   2006.0  11/11/2006  600.0
# 5905     25.0  ...   1/18/2008   21.0       1.0   2008.0   1/21/2008  625.0
#
#       TYPE  SOURCE  SOURCED Unnamed: 24
# ...

# %%
plt.scatter(approve.YEAROUT,approve["POS PCT"])

# %%
approve.head(10)
# Out:
#    OFFICE  STATE  OH      NAME  PARTY  ELECYR  ELECTP  QUESTION  POS PCT  \
# 0       3      1   1      Hill      1     NaN     NaN       1.0     60.0
# 1       3      1   2  Sparkman      1     NaN     NaN       1.0     58.0
# 2       3      1   5    Heflin      1     NaN     NaN       1.0     54.0
# 3       3      1   5    Heflin      1     NaN     NaN       1.0     55.0
# 4       3      1   5    Heflin      1     NaN     NaN       1.0     47.0
# 5       3      1   5    Heflin      1     NaN     NaN       1.0     57.0
# 6       3      1   5    Heflin      1     NaN     NaN       1.0     47.0
# 7       3      1   5    Heflin      1     NaN     NaN       1.0     47.0
# 8       3      1   5    Heflin      1  1978.0     1.0       1.0     51.0
# 9       3      1   5    Heflin      1     NaN     NaN       1.0     59.0
#
#    NEG PCT  ...      DATEIN DAYOUT  MONTHOUT  YEAROUT              DATEOUT  \
# 0     35.0  ...    9/1/1964    1.0       9.0   1964.0  1964-09-01 00:00:00
# ...

# %%
grouped = approve.groupby('YEAROUT').mean()
#plt.scatter(grouped["YEAROUT"],approve["POS PCT"])
grouped.head(5)
# Out:
#          OFFICE      STATE        OH     PARTY  ELECYR  ELECTP  QUESTION  \
# YEAROUT
# 1958.0      3.0  11.000000  2.333333  2.000000     NaN     NaN       1.0
# 1962.0      3.0  21.095238  4.547619  1.869048     NaN     NaN       1.0
# 1964.0      3.0  23.597015  4.388060  1.447761  1958.0     1.0       1.0
# 1966.0      3.0  19.187500  3.937500  1.187500     NaN     NaN       1.0
# 1968.0      3.0  29.000000  6.000000  1.000000     NaN     NaN       1.0
#
#            POS PCT    NEG PCT  DAYIN   MONTHIN  YEARIN  DAYOUT  MONTHOUT  \
# YEAROUT
# 1958.0   37.000000  26.333333    1.0  8.666667  1958.0     1.0  8.666667
# 1962.0   38.869048  21.154762    1.0  7.107143  1962.0     1.0  7.107143
# 1964.0   64.164179  24.074627    1.0  8.709091  1964.0     1.0  8.709091
# 1966.0   56.071429  26.928571    1.0  9.625000  1966.0     1.0  9.625000
# 1968.0   71.000000  17.000000    1.0  2.000000  1968.0     1.0  2.000000
#
#              SAMPLE  TYPE
# YEAROUT
# 1958.0   617.666667   2.0
# ...

# %%
plt.scatter(grouped.index, grouped["POS PCT"], label="Positive %")
plt.scatter(grouped.index, grouped["NEG PCT"], label="Negative %")
#plt.xlabel("Year")
#plt.ylabel("Percent Rating")
plt.legend()
plt.title("Average Rating of Senators by Year")
# Out:
# Text(0.5, 1.0, 'Average Rating of Senators by Year')

# %% [markdown]
# ### to compare to congress in general approval rating
# the data I need is here in this [Roper Database](https://ropercenter.cornell.edu/ipoll/search?collection=LSM&decade=1980s&experimental=NON&q=congress&tab=TREND), had to ask for free trial, waiting to hear back

# %% [markdown]
# ## horizontal bar charts

# %%
short = approve.iloc[:1500]
short.head()
short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OFFICE       1500 non-null   int64
#  1   STATE        1500 non-null   int64
#  2   OH           1500 non-null   int64
#  3   NAME         1500 non-null   object
#  4   PARTY        1500 non-null   int64
#  5   ELECYR       1385 non-null   float64
#  6   ELECTP       1384 non-null   float64
#  7   QUESTION     1492 non-null   float64
#  8   POS PCT      1500 non-null   float64
#  9   NEG PCT      1490 non-null   float64
#  10  RATING SC    1493 non-null   object
#  11  POLLSTER     1447 non-null   object
#  12  DAYIN        1390 non-null   float64
#  13  MONTHIN      1454 non-null   float64
#  14  YEARIN       1492 non-null   float64
#  15  DATEIN       1500 non-null   object
#  16  DAYOUT       1390 non-null   float64
#  17  MONTHOUT     1454 non-null   float64
# ...

# %%
#short

# %%
plt.scatter(short.YEARIN, short.NAME)
plt.hlines(short.NAME,short.YEARIN,short.YEAROUT,linewidth=1)
plt.figure(figsize=(50,10))

# %%
short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OFFICE       1500 non-null   int64
#  1   STATE        1500 non-null   int64
#  2   OH           1500 non-null   int64
#  3   NAME         1500 non-null   object
#  4   PARTY        1500 non-null   int64
#  5   ELECYR       1385 non-null   float64
#  6   ELECTP       1384 non-null   float64
#  7   QUESTION     1492 non-null   float64
#  8   POS PCT      1500 non-null   float64
#  9   NEG PCT      1490 non-null   float64
#  10  RATING SC    1493 non-null   object
#  11  POLLSTER     1447 non-null   object
#  12  DAYIN        1390 non-null   float64
#  13  MONTHIN      1454 non-null   float64
#  14  YEARIN       1492 non-null   float64
#  15  DATEIN       1500 non-null   object
#  16  DAYOUT       1390 non-null   float64
#  17  MONTHOUT     1454 non-null   float64
# ...

# %%
# this isn't working because ppl show up multiple times for multiple terms 
'''need to 
    - collapse all copies with the same name to be YEARIN min, YEAROUT.max
'''

shortE = short.loc[:,["NAME","YEARIN","YEAROUT"]]
shortE.set_index("NAME",inplace=True)
#print(shortE)

yin = shortE.groupby("NAME")["YEARIN"].min()
yout = shortE.groupby("NAME")["YEAROUT"].max()

lines = pd.merge(yin, yout, left_index=True, right_index=True) 

lines.head()
# Out:
#            YEARIN  YEAROUT
# NAME
# Akaka      1990.0   2006.0
# Allard     1998.0   2006.0
# Allott     1962.0   1964.0
# Armstrong  1985.0   1985.0
# Bennet     2009.0   2009.0

# %%
plt.scatter(lines.YEARIN, lines.index)
plt.scatter(lines.YEAROUT, lines.index)

plt.hlines(lines.index,lines.YEARIN,lines.YEAROUT,linewidth=1)
#plt.figure(figsize=(1,10))

'''
N = len(lines)
plt.gca().margins(x=0)
plt.gcf().canvas.draw()
tl = plt.gca().get_yticklabels()
maxsize = max([t.get_window_extent().height for t in tl])
m = .01 # inch margin
s = maxsize/plt.gcf().dpi*N+2*m
margin = m/plt.gcf().get_size_inches()[0]
plt.gcf().subplots_adjust(bottom=margin, top=1.-margin)

'''

plt.gcf().subplots_adjust(bottom=0, top=2)
plt.gcf().set_size_inches(s, plt.gcf().get_size_inches()[1])
plt.title("Senators' Terms between " + str(lines.YEARIN.min()) + " and " + str(lines.YEAROUT.max()) + ".")
# Out:
# Text(0.5, 1.0, "Senators' Terms between 1958.0 and 2009.0.")

# %% [markdown]
# ## trying in altair

# %%
#  need to solve TypeError: Object of type datetime is not JSON serializable
# successfully turned into int I think

# %%
alt.data_transformers.disable_max_rows()
approve2 = approve
print(approve2.head())
#approve2["YEAROUT"].replace(r'^\s+$', np.nan, inplace=True,regex=True)
approve2["YEAROUT"] = approve2["YEAROUT"].astype(str) #.str[:-2] #.astype(int)
# Out:
#    OFFICE  STATE  OH      NAME  PARTY  ELECYR  ELECTP  QUESTION  POS PCT  \
# 0       3      1   1      Hill      1     NaN     NaN       1.0     60.0
# 1       3      1   2  Sparkman      1     NaN     NaN       1.0     58.0
# 2       3      1   5    Heflin      1     NaN     NaN       1.0     54.0
# 3       3      1   5    Heflin      1     NaN     NaN       1.0     55.0
# 4       3      1   5    Heflin      1     NaN     NaN       1.0     47.0
#
#    NEG PCT  ...    DATEIN DAYOUT  MONTHOUT  YEAROUT              DATEOUT  \
# 0     35.0  ...  9/1/1964    1.0       9.0   1964.0  1964-09-01 00:00:00
# 1     34.0  ...  9/1/1964    1.0       9.0   1964.0  1964-09-01 00:00:00
# 2     46.0  ...    //1988    NaN       NaN   1988.0                 1988
# 3     45.0  ...    //1989    NaN       NaN   1989.0                 1989
# 4     53.0  ...    //1995    NaN       NaN   1995.0                 1995
#
#   SAMPLE  TYPE  SOURCE SOURCED Unnamed: 24
# 0  414.0   2.0       6     NaN         NaN
# ...

# %%
approve["YEAROUT"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5906 entries, 0 to 5905
# Series name: YEAROUT
# Non-Null Count  Dtype
# --------------  -----
# 5906 non-null   object
# dtypes: object(1)
# memory usage: 46.3+ KB

# %%
approve2.info()
approve2.YEAROUT.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5886 entries, 0 to 5905
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OFFICE       5886 non-null   int64
#  1   STATE        5886 non-null   int64
#  2   OH           5886 non-null   int64
#  3   NAME         5886 non-null   object
#  4   PARTY        5886 non-null   int64
#  5   ELECYR       5572 non-null   float64
#  6   ELECTP       5563 non-null   float64
#  7   QUESTION     5804 non-null   float64
#  8   POS PCT      5883 non-null   float64
#  9   NEG PCT      5822 non-null   float64
#  10  RATING SC    5866 non-null   object
#  11  POLLSTER     5817 non-null   object
#  12  DAYIN        5650 non-null   float64
#  13  MONTHIN      5815 non-null   float64
#  14  YEARIN       5886 non-null   float64
#  15  DATEIN       5886 non-null   object
#  16  DAYOUT       5651 non-null   float64
#  17  MONTHOUT     5814 non-null   float64
# ...

# %%
approve2 = approve2.replace("nan",np.nan)
approve2.dropna(subset=['YEAROUT'], inplace = True)
#approve2[approve2["YEAROUT"]=='nan']
#dropa = approve2.dropna(subset=['YEAROUT'])
#dropa["YEAROUT"].unique()
#[approve2["YEARIN"].dropna('nan')]

# %%
approve2["YEAROUT"] = approve2["YEAROUT"].astype(str) #.str[:-2] #.astype(int)
approve2["YEAROUT"] = approve2["YEAROUT"].str[:-2] #.unique() #astype(int).head()
approve2["YEAROUT"] = approve2["YEAROUT"].astype(int)

# %%
approve2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5886 entries, 0 to 5905
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OFFICE       5886 non-null   int64
#  1   STATE        5886 non-null   int64
#  2   OH           5886 non-null   int64
#  3   NAME         5886 non-null   object
#  4   PARTY        5886 non-null   int64
#  5   ELECYR       5572 non-null   float64
#  6   ELECTP       5563 non-null   float64
#  7   QUESTION     5804 non-null   float64
#  8   POS PCT      5883 non-null   float64
#  9   NEG PCT      5822 non-null   float64
#  10  RATING SC    5866 non-null   object
#  11  POLLSTER     5817 non-null   object
#  12  DAYIN        5650 non-null   float64
#  13  MONTHIN      5815 non-null   float64
#  14  YEARIN       5886 non-null   float64
#  15  DATEIN       5886 non-null   object
#  16  DAYOUT       5651 non-null   float64
#  17  MONTHOUT     5814 non-null   float64
# ...

# %%
# try with altair 
source = approve2

alt.Chart(source).mark_circle(size=60).encode(
    x='YEAROUT',
    y='POS PCT',
    color='Party',
    tooltip=['NAME', 'PARTY', 'YEAROUT', 'POS PCT']
).interactive()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/altair/vegalite/v4/api.py:2020, in Chart.to_dict(self, *args, **kwargs)
#    2018     copy.data = core.InlineData(values=[{}])
#    2019     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020 return super().to_dict(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/altair/vegalite/v4/api.py:374, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     372 copy = self.copy(deep=False)
#     373 original_data = getattr(copy, "data", Undefined)
# --> 374 copy.data = _prepare_data(original_data, context)
#     376 if original_data is not Undefined:
#     377     context["data"] = original_data
#
# File /opt/anaconda3/lib/python3.9/site-packages/altair/vegalite/v4/api.py:97, in _prepare_data(data, context)
#      95 # consolidate inline data to top-level datasets
# ...

# %%
approve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OFFICE       5906 non-null   int64
#  1   STATE        5906 non-null   int64
#  2   OH           5906 non-null   int64
#  3   NAME         5906 non-null   object
#  4   PARTY        5906 non-null   int64
#  5   ELECYR       5581 non-null   float64
#  6   ELECTP       5572 non-null   float64
#  7   QUESTION     5824 non-null   float64
#  8   POS PCT      5903 non-null   float64
#  9   NEG PCT      5840 non-null   float64
#  10  RATING SC    5884 non-null   object
#  11  POLLSTER     5831 non-null   object
#  12  DAYIN        5650 non-null   float64
#  13  MONTHIN      5815 non-null   float64
#  14  YEARIN       5890 non-null   float64
#  15  DATEIN       5906 non-null   object
#  16  DAYOUT       5651 non-null   float64
#  17  MONTHOUT     5814 non-null   float64
# ...
